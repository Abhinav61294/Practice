# %%
import matplotlib.pyplot as plt
plt.scatter(2,3)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter([2,5],[3,6])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter([2,5,3,4,7] ,[3,6,5,1,8])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter([2,3,5],[1,7,6],999)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter([2,3,5],[1,7,6],[10,1000,300])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter([2,3,5],[1,7,6],(10,1000,3000),("red","green","purple"))
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter([2,3,5],[1,7,6],(10,1000,3000),["red","green","purple"],("*"))
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([7,2,10],[1,7,3])

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3],[1,2,3])

# %%
import matplotlib.pyplot as plt
plt.plot([1.5,2.75,1.5,2.75,2.125,1.5],[1.25,4.25,4.25,1.25,6,1.25])

# %%
x=[1,2,3]
len(x)
print(len(x))
print()
z=range(3)
for i in range(3):
    print(i)
# Out:
# 3
#
# 0
# 1
# 2

# %%
import matplotlib.pyplot as plt
value = [1,8,7,4,9]
plt.plot(value)

# %%
import matplotlib.pyplot as plt
value = [1,8,7,4,9]
plt.plot(value)
x=plt.plot(value,linewidth=17)
plt.show()
print(x)

# %%
import matplotlib.pyplot as plt
x=plt.title("Square numbers", fontsize=27)
plt.xlabel("Value", fontsize=80)
plt.ylabel("Square of Values", fontsize=40)
plt.tick_params(axis="x",labelsize=20)
plt.tick_params(axis="y",labelsize=50)
plt.plot(value)
plt.show()
x
# Out:
# Text(0.5, 1.0, 'Square numbers')

# %%
import matplotlib.pyplot as plt
input_values=[1,2,3,4,5]
squares=[1,4,9,16,25]
cubes=[1,8,27,64,125]
f_power=[1,32,243,1024,3125]
plt.plot(input_values,squares,linewidth=5,c="red",label="squares")
plt.plot(input_values,cubes,linewidth=5,label="cubes")
plt.plot(input_values,f_power,linewidth=5,label="f_power")
plt.legend()
plt.xlim(2,4,5)
plt.show()
